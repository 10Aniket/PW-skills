# %% [markdown]
# Ans1

# %% [markdown]
# matplotlib is inbuild liabrary in python. this module is used for visualization and here are some example of matplotlin.pylot
# visualization example
# bar plot,pie plot,line plot,box plot and scatter plot

# %% [markdown]
# Ans2

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,5))
plt.scatter(x,y,c="red")
plt.title("Scatter plot")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# Ans3

# %%
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# subplot is use to make a muiltiple plot in one go in single block of code

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)
plt.title("line plot")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# Ans4

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Ans5

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ef9d4f3a30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ef9d502190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ef9d4f36a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef9d5028b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef9d502c40>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ef9d564850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ef9d564f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ef9d5644c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef9d56f6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef9d56fa60>],
#  'means': []}
